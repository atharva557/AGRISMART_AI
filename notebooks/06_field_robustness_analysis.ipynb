# %% [markdown]
# # field robustness analysis
#
# Status: not started. Add experiments, dataset provenance, and measured results here. Keep reusable training and evaluation code in model/. Never tune on the organizers' held-out test set.
